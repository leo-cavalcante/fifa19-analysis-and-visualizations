# %% [markdown]
# # Video Games Sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sbs
import squarify
import os

# %% [markdown]
# # Explanation for the database, from Kaggle website

# %% [markdown]
# ### Link to website
# https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings
#
# ### Context
# Motivated by Gregory Smith's web scrape of VGChartz Video Games Sales, this data set simply extends the number of variables with another web scrape from Metacritic. Unfortunately, there are missing observations as Metacritic only covers a subset of the platforms. Also, a game may not have all the observations of the additional variables discussed below. Complete cases are ~ 6,900
#
# ### Content
# Alongside the fields: Name, Platform, YearofRelease, Genre, Publisher, NASales, EUSales, JPSales, OtherSales, Global_Sales, we have:
#
# - **Critic_score** - Aggregate score compiled by Metacritic staff
# - **Criticcount** - The number of critics used in coming up with the Criticscore
# - **User_score** - Score by Metacritic's subscribers
# - **Usercount** - Number of users who gave the userscore
# - **Developer** - Party responsible for creating the game
# - **Rating** - The ESRB ratings

# %% [markdown]
# ## Importing the database

# %%
os.getcwd()
# Out:
# '/Users/oleoaraujo/Documents/GitHub/data-ft-par-labs/Projects/Week-4'

# %%
games = pd.read_csv("data/Video_Games_Sales_as_at_22_Dec_2016.csv")
games.head(15)
# Out:
#                            Name Platform  Year_of_Release         Genre  \
# 0                    Wii Sports      Wii           2006.0        Sports
# 1             Super Mario Bros.      NES           1985.0      Platform
# 2                Mario Kart Wii      Wii           2008.0        Racing
# 3             Wii Sports Resort      Wii           2009.0        Sports
# 4      Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                        Tetris       GB           1989.0        Puzzle
# 6         New Super Mario Bros.       DS           2006.0      Platform
# 7                      Wii Play      Wii           2006.0          Misc
# 8     New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                     Duck Hunt      NES           1984.0       Shooter
# 10                   Nintendogs       DS           2005.0    Simulation
# 11                Mario Kart DS       DS           2005.0        Racing
# ...

# %% [markdown]
# ### Understanding my data

# %%
games.shape
# Out:
# (16719, 16)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
# Numeric variables
print(games.select_dtypes(include='number').dtypes)
# Out:
# Year_of_Release    float64
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Count         float64
# dtype: object

# %%
# Categorical variables
print(games.select_dtypes(include='object').dtypes)
# Out:
# Name          object
# Platform      object
# Genre         object
# Publisher     object
# User_Score    object
# Developer     object
# Rating        object
# dtype: object

# %%
games.describe(include="all").T
# Out:
#                    count unique                          top  freq  \
# Name               16717  11562  Need for Speed: Most Wanted    12
# Platform           16719     31                          PS2  2161
# Year_of_Release  16450.0    NaN                          NaN   NaN
# Genre              16717     12                       Action  3370
# Publisher          16665    581              Electronic Arts  1356
# NA_Sales         16719.0    NaN                          NaN   NaN
# EU_Sales         16719.0    NaN                          NaN   NaN
# JP_Sales         16719.0    NaN                          NaN   NaN
# Other_Sales      16719.0    NaN                          NaN   NaN
# Global_Sales     16719.0    NaN                          NaN   NaN
# Critic_Score      8137.0    NaN                          NaN   NaN
# Critic_Count      8137.0    NaN                          NaN   NaN
# User_Score         10015     96                          tbd  2425
# ...

# %% [markdown]
# ## Analyzing and cleaning the database

# %%
games.Developer.fillna(value="UNKNOWN").value_counts()
# Out:
# UNKNOWN                            6623
# Ubisoft                             204
# EA Sports                           172
# EA Canada                           167
# Konami                              162
#                                    ...
# Big Time Software                     1
# The Tangentlemen                      1
# Activision, Activision Blizzard       1
# Mastertronic, V5 Play Studio          1
# Cygames                               1
# Name: Developer, Length: 1697, dtype: int64

# %%
games.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# We have 2 lines without Name, Genre, Critic Count & Score, User Count & Score, Developer and Rating.
# But let's not drop them for now, since it doesn't seem useful to make analysis by Name of the Game.
games[games.Name.isna()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 659        0.53      0.00         0.08          2.39           NaN
# 14246      0.00      0.03         0.00          0.03           NaN
#
#        Critic_Count User_Score  User_Count Developer Rating
# 659             NaN        NaN         NaN       NaN    NaN
# 14246           NaN        NaN         NaN       NaN    NaN

# %%
games_test = games.Year_of_Release.fillna(0)

# %%
games_test.isna().sum()
# Out:
# 0

# %%
#games_test.str.replace(None,0)
games_test = games_test.astype(int)
games_test.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Visualizing some data

# %% [markdown]
# #### Having in mind that our database is from 2016, let's check out the distribution of Game releases throughout the years.

# %%
# Let's do this by plotting a histogram with the distribution of releases by year
games.Year_of_Release.hist(bins=20, figsize=(10,4), grid=True, color = "purple")
plt.xlabel("Years", size=15)
plt.ylabel("Number of releases", size=15)
plt.show()

# %% [markdown]
# #### Let's check out the , let's check out the distribution of Game releases throughout the years.

# %%
df = games.Publisher.value_counts()

squarify.plot(sizes=games.Publisher.value_counts().values, label=games.Publisher.value_counts().index, color=["red","green","blue", "grey"], alpha=.4 )
plt.axis('off')
plt.show()
